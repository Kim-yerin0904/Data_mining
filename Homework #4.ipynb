# %% [markdown]
# ### Q1

# %%
#1)
import pandas as pd 
data = pd.read_excel("Students.xls")

# %%
data
# Out:
#    Semester             Name                Course  Mark  Attended
# 0   FSS2010    Alex Krausche    Database Systems I   1.3        13
# 1   FSS2010     Tanja Becker    Database Systems I   2.0        12
# 2   FSS2010   Mariano Selina    Database Systems I   1.7         5
# 3   FSS2010     Otto Blacher    Database Systems I   2.3        13
# 4   FSS2010     Frank Fester    Database Systems I   2.0        13
# 5   FSS2010   Susanne Müller    Database Systems I   3.0        12
# 6   FSS2010     Avid Morvita    Database Systems I   4.0        13
# 7   FSS2010      Steve Queck    Database Systems I   2.7         8
# 8   FSS2010  Michaela Martke    Database Systems I   5.0         5
# 9   FSS2010    Ulrich Gester    Database Systems I   5.0         7
# 10  HWS2010    Alex Krausche   Database Systems II   1.0        12
# 11  HWS2010     Tanja Becker   Database Systems II   1.7        13
# 12  HWS2010   Mariano Selina   Database Systems II   2.0        10
# ...

# %%
#2)
import matplotlib.pyplot as plt
plt.hist(data["Mark"])
# Out:
# (array([5., 4., 9., 5., 4., 7., 1., 2., 0., 4.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
#3)
is_FSS2010 = data['Semester'] == "FSS2010"
FSS2010 = data[is_FSS2010]
FSS2010
# Out:
#    Semester             Name                Course  Mark  Attended
# 0   FSS2010    Alex Krausche    Database Systems I   1.3        13
# 1   FSS2010     Tanja Becker    Database Systems I   2.0        12
# 2   FSS2010   Mariano Selina    Database Systems I   1.7         5
# 3   FSS2010     Otto Blacher    Database Systems I   2.3        13
# 4   FSS2010     Frank Fester    Database Systems I   2.0        13
# 5   FSS2010   Susanne Müller    Database Systems I   3.0        12
# 6   FSS2010     Avid Morvita    Database Systems I   4.0        13
# 7   FSS2010      Steve Queck    Database Systems I   2.7         8
# 8   FSS2010  Michaela Martke    Database Systems I   5.0         5
# 9   FSS2010    Ulrich Gester    Database Systems I   5.0         7
# 17  FSS2010    Alex Krausche  Software Engineering   2.0        13
# 18  FSS2010   Mariano Selina  Software Engineering   1.3         6
# 19  FSS2010     Otto Blacher  Software Engineering   2.0        12
# ...

# %%
#4)
plt.hist(FSS2010["Mark"])
# Out:
# (array([4., 2., 7., 3., 3., 6., 0., 2., 0., 2.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# #5)
#
# 2.0

# %% [markdown]
# ### Q2

# %%
#1)
plt.scatter(FSS2010["Attended"],FSS2010["Mark"])

# %%
#2)
plt.scatter(FSS2010["Attended"],FSS2010["Mark"])
plt.xlabel("Attended")
plt.ylabel("Mark")
# Out:
# Text(0, 0.5, 'Mark')

# %% [markdown]
# #3)
#
# Attended의 수가 크면 대체적으로 Mark도 낮다.

# %% [markdown]
# # Q3

# %%
#1)
Name_mean = FSS2010.groupby("Name").mean()
Name_mean
# Out:
#                      Mark   Attended
# Name
# Alex Krausche    1.433333  12.666667
# Avid Morvita     3.100000  11.333333
# Frank Fester     2.233333  12.666667
# Mariano Selina   1.566667   5.000000
# Michaela Martke  3.766667   6.333333
# Otto Blacher     2.100000  12.333333
# Steve Queck      2.800000   8.333333
# Susanne Müller   2.433333  12.000000
# Tanja Becker     1.650000  11.500000
# Ulrich Gester    4.000000   8.333333

# %%
#2)
plt.scatter(Name_mean["Attended"],Name_mean["Mark"])
plt.xlabel("Attended")
plt.ylabel("Mark")
plt.annotate('Alex Krausche',(12.666667,1.433333))
plt.annotate('Avid Morvita',(11.333333,3.100000))
plt.annotate('Frank Fester',(12.666667,2.233333))
plt.annotate('Mariano Selina',(5.000000,1.566667))
plt.annotate('Michaela Martke',(6.333333,3.766667))
plt.annotate('Otto Blacher',(12.333333,2.100000))
plt.annotate('Steve Queck',(8.333333,2.800000))
plt.annotate('Susanne Müller',(12.000000,2.433333))
plt.annotate('Tanja Becker',(11.500000,1.650000))
plt.annotate('Ulrich Gester',(8.333333,4.000000))
# Out:
# Text(8.333333, 4.0, 'Ulrich Gester')

# %% [markdown]
# #3)
#
# 모든 학생에게 적용되는 것 같다. 이름을 기준으로 다시 그룹화하고 나머지 열의 평균을 구해 산점도를 그렸을 때 Attended 수가 많은 학생의 Mark가 대체로 낮았고, 6~9사이의 Attended 수인 학생의 Mark가 좋은 편이다.
